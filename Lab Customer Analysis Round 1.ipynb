# %%
import pandas as pd

# %%
#importar los archivos
file1 = pd.read_csv(r"C:\Users\danie\Desktop\Boot Camp\Labs\Lab_1\file1.csv")

# %%
file2= pd.read_csv(r"C:\Users\danie\Desktop\Boot Camp\Labs\Lab_1\file2.csv")

# %%
file3= pd.read_csv(r"C:\Users\danie\Desktop\Boot Camp\Labs\Lab_1\file3.csv")

# %%
#mostar el shape the DataFrame
print("File 1 Shape:", file1.shape)
# Out:
# File 1 Shape: (4008, 11)

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
print("File 2 Shape:", file2.shape)
# Out:
# File 2 Shape: (996, 11)

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
print("File 3 Shape:", file3.shape)
# Out:
# File 3 Shape: (7070, 11)

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#estandarizamos las cabeceras de las columnas
file1.columns = file1.columns.str.lower().str.replace(' ', '_')#con esto quitamos las mayusculas y remplazmos espacios con _

# %%
file1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
file2.columns = file2.columns.str.lower().str.replace(' ', '_')

# %%
file2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
file3.columns = file3.columns.str.lower().str.replace(' ', '_')

# %%
file3.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
#concatenar los tres DF
combined_df = pd.concat([file1, file2, file3], ignore_index=True)

# %%
combined_df.shape
# Out:
# (12074, 12)

# %%
combined_df
# Out:
#       customer          st gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316         NaN      M              Bachelor
# 12070  PK87824         NaN      F               College
# 12071  TD14365         NaN      M              Bachelor
# 12072  UP19263         NaN      M               College
# 12073  Y167826         NaN      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
#Que columna son numericas
numerical_columns = combined_df.select_dtypes(include=['float64']).columns.tolist()
print("Numerical Columns:", numerical_columns)
# Out:
# Numerical Columns: ['income', 'monthly_premium_auto', 'total_claim_amount']

# %%
#que columnas son categorical
categorical_columns = combined_df.select_dtypes(exclude=['float64']).columns.tolist()
print("Categorical Columns:", categorical_columns)
# Out:
# Categorical Columns: ['customer', 'st', 'gender', 'education', 'customer_lifetime_value', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'state']

# %%
#borrar la columna education y the number of open complaints del DF
combined_df.drop(columns=['education', 'number_of_open_complaints'], inplace=True)

# %%
combined_df
# Out:
#       customer          st gender customer_lifetime_value   income  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316         NaN      M             23405.98798  71941.0
# 12070  PK87824         NaN      F             3096.511217  21604.0
# 12071  TD14365         NaN      M             8163.890428      0.0
# 12072  UP19263         NaN      M             7524.442436  21941.0
# 12073  Y167826         NaN      M             2611.836866      0.0
#
#        monthly_premium_auto     policy_type  vehicle_class  \
# 0                    1000.0   Personal Auto  Four-Door Car
# ...

# %%
#corrige los valores en la columna customer 
combined_df['customer_lifetime_value'] = pd.to_numeric(combined_df['customer_lifetime_value'].str.replace('%', '')) * 100

# %%
#vamos a chequear si hay filas repetidas
combined_df.drop_duplicates(inplace=True)

# %%
#eliminamos los clientes que tengan un ingreso de 0 o menos
combined_df = combined_df[combined_df['income'] > 0]

# %%
combined_df
# Out:
#       customer          st gender  customer_lifetime_value   income  \
# 2      AI49188      Nevada      F              128874317.0  48767.0
# 4      GA49547  Washington      M               53630765.0  36357.0
# 5      OC83172      Oregon      F               82562978.0  62902.0
# 6      XZ87318      Oregon      F               53808986.0  55350.0
# 8      DY87989      Oregon      M              241275040.0  14072.0
# ...        ...         ...    ...                      ...      ...
# 12067  TF56202         NaN      M                      NaN  66367.0
# 12068  YM19146         NaN      F                      NaN  47761.0
# 12069  LA72316         NaN      M                      NaN  71941.0
# 12070  PK87824         NaN      F                      NaN  21604.0
# 12072  UP19263         NaN      M                      NaN  21941.0
#
#        monthly_premium_auto     policy_type  vehicle_class  \
# 2                     108.0   Personal Auto   Two-Door Car
# ...

# %%
combined_df.shape
# Out:
# (6840, 10)
